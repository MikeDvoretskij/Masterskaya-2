# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
with open('model.pkl', 'rb') as fid:
    model_regressor = pickle.load(fid)
    fid.close()

# %%
imp = pd.Series(model_regressor.estimators_[0].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[1].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[2].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[3].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[4].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[5].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[6].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[7].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[8].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[9].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[10].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[11].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[12].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[13].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[14].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[15].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[16].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[17].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[18].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[19].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[20].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[21].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[22].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[23].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[24].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[25].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[26].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[27].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[28].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[29].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[30].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[31].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[32].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[33].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[34].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[35].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[36].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[37].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[38].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[39].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[40].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[41].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[42].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[43].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[44].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[45].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[46].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[47].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[48].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[49].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[50].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[51].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[52].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[53].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[54].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[55].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[56].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[57].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[58].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[59].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[60].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[61].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[62].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[63].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[64].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[65].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[66].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[67].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[68].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[69].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[70].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()

# %%
imp = pd.Series(model_regressor.estimators_[71].get_feature_importance(), [x for x in range(1, 73)])
fig, ax = plt.subplots(figsize=(16,14))
imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()
